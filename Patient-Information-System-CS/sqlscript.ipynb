-- %% [markdown]
-- # [Group2-PIS-V2]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [Group2-PIS-V2]    Script Date: 10/29/2025 2:26:09 AM ******/
CREATE DATABASE [Group2-PIS-V2]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'Group2-PIS-V2', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.MSSQLSERVER\MSSQL\DATA\Group2-PIS-V2.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'Group2-PIS-V2_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.MSSQLSERVER\MSSQL\DATA\Group2-PIS-V2_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [Group2-PIS-V2] SET COMPATIBILITY_LEVEL = 160
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [Group2-PIS-V2].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [Group2-PIS-V2] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [Group2-PIS-V2] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [Group2-PIS-V2] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [Group2-PIS-V2] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [Group2-PIS-V2] SET ARITHABORT OFF 
GO
ALTER DATABASE [Group2-PIS-V2] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [Group2-PIS-V2] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [Group2-PIS-V2] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [Group2-PIS-V2] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [Group2-PIS-V2] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [Group2-PIS-V2] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [Group2-PIS-V2] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [Group2-PIS-V2] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [Group2-PIS-V2] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [Group2-PIS-V2] SET  DISABLE_BROKER 
GO
ALTER DATABASE [Group2-PIS-V2] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [Group2-PIS-V2] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [Group2-PIS-V2] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [Group2-PIS-V2] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [Group2-PIS-V2] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [Group2-PIS-V2] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [Group2-PIS-V2] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [Group2-PIS-V2] SET RECOVERY FULL 
GO
ALTER DATABASE [Group2-PIS-V2] SET  MULTI_USER 
GO
ALTER DATABASE [Group2-PIS-V2] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [Group2-PIS-V2] SET DB_CHAINING OFF 
GO
ALTER DATABASE [Group2-PIS-V2] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [Group2-PIS-V2] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [Group2-PIS-V2] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [Group2-PIS-V2] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
EXEC sys.sp_db_vardecimal_storage_format N'Group2-PIS-V2', N'ON'
GO
ALTER DATABASE [Group2-PIS-V2] SET QUERY_STORE = ON
GO
ALTER DATABASE [Group2-PIS-V2] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [dbo].[Appointment]

-- %%
USE [Group2-PIS-V2]
GO

-- %%
/****** Object:  Table [dbo].[Appointment]    Script Date: 10/29/2025 2:26:09 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Appointment](
	[Appointment_ID] [int] NOT NULL,
	[Appointment_ID_Number] [varchar](50) NOT NULL,
	[Assigned_Patient_ID] [int] NOT NULL,
	[Assigned_Doctor_ID] [int] NOT NULL,
	[Appointment_Schedule] [datetime] NOT NULL,
	[Appointment_Purpose] [varchar](100) NOT NULL,
	[Appointment_Status] [tinyint] NOT NULL,
	[Medical_Records_Text] [varchar](800) NULL,
	[Diagnosis_Text] [varchar](500) NULL,
	[Treatment_Text] [varchar](500) NULL,
	[Prescriptions_Text] [varchar](500) NULL,
 CONSTRAINT [PK_Appointment] PRIMARY KEY CLUSTERED 
(
	[Appointment_ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Appointment_Invoice_Link]

-- %%
/****** Object:  Table [dbo].[Appointment_Invoice_Link]    Script Date: 10/29/2025 2:26:09 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Appointment_Invoice_Link](
	[Link_ID] [int] NOT NULL,
	[Appointment_ID] [int] NOT NULL,
	[Bill_ID] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Link_ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Audit_Log]

-- %%
/****** Object:  Table [dbo].[Audit_Log]    Script Date: 10/29/2025 2:26:09 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Audit_Log](
	[Log_ID] [int] NOT NULL,
	[User_ID] [int] NOT NULL,
	[Action] [varchar](100) NOT NULL,
	[Table_Name] [varchar](50) NOT NULL,
	[Record_ID] [int] NULL,
	[Action_Date] [datetime] NOT NULL,
	[Details] [varchar](500) NULL,
PRIMARY KEY CLUSTERED 
(
	[Log_ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Bills]

-- %%
/****** Object:  Table [dbo].[Bills]    Script Date: 10/29/2025 2:26:09 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Bills](
	[Bill_ID] [int] NOT NULL,
	[Bill_ID_Number] [varchar](50) NOT NULL,
	[Assigned_Patient_ID] [int] NOT NULL,
	[Amount] [money] NOT NULL,
	[Description] [varchar](100) NOT NULL,
	[Date_Billed] [datetime] NOT NULL,
	[Status] [tinyint] NOT NULL,
	[Payment_Method] [varchar](50) NULL,
 CONSTRAINT [PK_Bills] PRIMARY KEY CLUSTERED 
(
	[Bill_ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Department]

-- %%
/****** Object:  Table [dbo].[Department]    Script Date: 10/29/2025 2:26:09 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Department](
	[Department_ID] [int] NOT NULL,
	[Department_Name] [varchar](50) NOT NULL,
	[Description] [varchar](200) NULL,
PRIMARY KEY CLUSTERED 
(
	[Department_ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Doctor]

-- %%
/****** Object:  Table [dbo].[Doctor]    Script Date: 10/29/2025 2:26:09 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Doctor](
	[Doctor_ID] [int] NOT NULL,
	[Doctor_ID_Number] [varchar](10) NOT NULL,
	[License_Number] [varchar](20) NOT NULL,
	[Department] [varchar](50) NOT NULL,
	[Specialization] [varchar](50) NOT NULL,
	[Employment_Date] [date] NOT NULL,
	[Regular_Staff] [bit] NOT NULL,
	[Residency_Date] [date] NULL,
	[Supervisor_ID] [varchar](50) NULL,
	[Salary] [money] NOT NULL,
	[Person_ID] [int] NOT NULL,
	[Approval_Status] [tinyint] NOT NULL,
 CONSTRAINT [PK_Doctor] PRIMARY KEY CLUSTERED 
(
	[Doctor_ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Insurance]

-- %%
/****** Object:  Table [dbo].[Insurance]    Script Date: 10/29/2025 2:26:09 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Insurance](
	[Insurance_ID] [int] NOT NULL,
	[Policy_Number] [varchar](50) NOT NULL,
	[Provider_Name] [varchar](100) NOT NULL,
	[Coverage_Type] [varchar](50) NOT NULL,
	[Coverage_Amount] [money] NULL,
	[Expiry_Date] [date] NULL,
	[Assigned_Patient_ID] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Insurance_ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Medical_Records]

-- %%
/****** Object:  Table [dbo].[Medical_Records]    Script Date: 10/29/2025 2:26:09 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Medical_Records](
	[Record_ID] [int] NOT NULL,
	[Record_ID_Number] [varchar](50) NOT NULL,
	[Record_Date] [date] NOT NULL,
	[Assigned_Patient_ID] [int] NOT NULL,
	[Assigned_Doctor_ID] [int] NOT NULL,
	[Diagnosis] [varchar](500) NOT NULL,
	[Treatment] [varchar](500) NOT NULL,
	[Prescriptions] [varchar](500) NOT NULL,
 CONSTRAINT [PK_Medical_Records] PRIMARY KEY CLUSTERED 
(
	[Record_ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Nurse]

-- %%
/****** Object:  Table [dbo].[Nurse]    Script Date: 10/29/2025 2:26:09 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Nurse](
	[Nurse_ID] [int] NOT NULL,
	[Nurse_ID_Number] [varchar](10) NOT NULL,
	[License_Number] [varchar](20) NOT NULL,
	[Department] [varchar](50) NOT NULL,
	[Specialization] [varchar](50) NOT NULL,
	[Employment_Date] [date] NOT NULL,
	[Regular_Staff] [bit] NOT NULL,
	[Residency_Date] [date] NULL,
	[Supervisor_ID] [nchar](10) NULL,
	[Salary] [money] NOT NULL,
	[Person_ID] [int] NOT NULL,
 CONSTRAINT [PK_Nurse] PRIMARY KEY CLUSTERED 
(
	[Nurse_ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Patient]

-- %%
/****** Object:  Table [dbo].[Patient]    Script Date: 10/29/2025 2:26:09 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Patient](
	[Patient_ID] [int] NOT NULL,
	[Person_ID] [int] NOT NULL,
	[Assigned_Doctor_ID] [int] NOT NULL,
	[Assigned_Nurse_ID] [int] NOT NULL,
	[Patient_ID_Number] [varchar](20) NOT NULL,
	[Allergens] [varchar](50) NULL,
	[Blood_Type] [varchar](5) NOT NULL,
	[Date_Admitted] [datetime] NOT NULL,
	[Date_Discharged] [datetime] NULL,
	[Medical_History] [varchar](800) NOT NULL,
	[Current_Medications] [varchar](500) NULL,
	[Room_ID] [int] NOT NULL,
	[Medical_Records] [int] NULL,
	[Bill_ID] [int] NOT NULL,
	[Status] [tinyint] NOT NULL,
 CONSTRAINT [PK_Patient] PRIMARY KEY CLUSTERED 
(
	[Patient_ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Person]

-- %%
/****** Object:  Table [dbo].[Person]    Script Date: 10/29/2025 2:26:09 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Person](
	[Person_ID] [int] NOT NULL,
	[Last_Name] [varchar](100) NOT NULL,
	[Given_Name] [varchar](100) NOT NULL,
	[MIddle_Name] [varchar](100) NULL,
	[Suffix] [varchar](5) NULL,
	[Birthdate] [date] NOT NULL,
	[Sex] [varchar](10) NOT NULL,
	[Contact_Number] [bigint] NOT NULL,
	[Address] [varchar](500) NOT NULL,
	[Emergency_Contact] [varchar](100) NOT NULL,
	[Relationship_to_Emergency_Contact] [varchar](15) NOT NULL,
	[Email] [varchar](100) NULL,
	[Nationality] [varchar](50) NOT NULL,
 CONSTRAINT [PK_Person] PRIMARY KEY CLUSTERED 
(
	[Person_ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Room]

-- %%
/****** Object:  Table [dbo].[Room]    Script Date: 10/29/2025 2:26:09 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Room](
	[Room_ID] [int] NOT NULL,
	[Room_Number] [smallint] NOT NULL,
	[Room_Type] [varchar](25) NOT NULL,
	[Capacity] [tinyint] NOT NULL,
	[Assigned_Patient_ID] [int] NULL,
 CONSTRAINT [PK_Room] PRIMARY KEY CLUSTERED 
(
	[Room_ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Staff]

-- %%
/****** Object:  Table [dbo].[Staff]    Script Date: 10/29/2025 2:26:09 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Staff](
	[Staff_ID] [int] NOT NULL,
	[Staff_ID_Number] [varchar](10) NOT NULL,
	[Department] [varchar](50) NOT NULL,
	[Employment_Date] [date] NOT NULL,
	[Regular_Staff] [bit] NOT NULL,
	[Supervisor_ID] [int] NULL,
	[Salary] [money] NOT NULL,
	[Person_ID] [int] NOT NULL,
 CONSTRAINT [PK_Staff] PRIMARY KEY CLUSTERED 
(
	[Staff_ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[User]

-- %%
/****** Object:  Table [dbo].[User]    Script Date: 10/29/2025 2:26:09 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[User](
	[User_ID] [int] NOT NULL,
	[Username] [varchar](20) NOT NULL,
	[Password] [varchar](500) NOT NULL,
	[Associated_Person_ID] [int] NOT NULL,
	[User_Role] [varchar](20) NOT NULL,
 CONSTRAINT [PK_User] PRIMARY KEY CLUSTERED 
(
	[User_ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [DF__Audit_Log__Actio__7C4F7684]

-- %%
ALTER TABLE [dbo].[Audit_Log] ADD  DEFAULT (getdate()) FOR [Action_Date]
GO

-- %% [markdown]
-- # [DF__Doctor__Approval__71D1E811]

-- %%
ALTER TABLE [dbo].[Doctor] ADD  DEFAULT ((0)) FOR [Approval_Status]
GO

-- %% [markdown]
-- # [DF__Patient__Status__72C60C4A]

-- %%
ALTER TABLE [dbo].[Patient] ADD  DEFAULT ((1)) FOR [Status]
GO

-- %% [markdown]
-- # [DF__User__User_Role__70DDC3D8]

-- %%
ALTER TABLE [dbo].[User] ADD  DEFAULT ('Patient') FOR [User_Role]
GO

-- %% [markdown]
-- # [FK_Appointment_Doctor]

-- %%
ALTER TABLE [dbo].[Appointment]  WITH CHECK ADD  CONSTRAINT [FK_Appointment_Doctor] FOREIGN KEY([Assigned_Doctor_ID])
REFERENCES [dbo].[Doctor] ([Doctor_ID])
GO
ALTER TABLE [dbo].[Appointment] CHECK CONSTRAINT [FK_Appointment_Doctor]
GO

-- %% [markdown]
-- # [FK_Appointment_Patient]

-- %%
ALTER TABLE [dbo].[Appointment]  WITH CHECK ADD  CONSTRAINT [FK_Appointment_Patient] FOREIGN KEY([Assigned_Patient_ID])
REFERENCES [dbo].[Patient] ([Patient_ID])
GO
ALTER TABLE [dbo].[Appointment] CHECK CONSTRAINT [FK_Appointment_Patient]
GO

-- %% [markdown]
-- # [FK_Link_Appointment]

-- %%
ALTER TABLE [dbo].[Appointment_Invoice_Link]  WITH CHECK ADD  CONSTRAINT [FK_Link_Appointment] FOREIGN KEY([Appointment_ID])
REFERENCES [dbo].[Appointment] ([Appointment_ID])
GO
ALTER TABLE [dbo].[Appointment_Invoice_Link] CHECK CONSTRAINT [FK_Link_Appointment]
GO

-- %% [markdown]
-- # [FK_Link_Bill]

-- %%
ALTER TABLE [dbo].[Appointment_Invoice_Link]  WITH CHECK ADD  CONSTRAINT [FK_Link_Bill] FOREIGN KEY([Bill_ID])
REFERENCES [dbo].[Bills] ([Bill_ID])
GO
ALTER TABLE [dbo].[Appointment_Invoice_Link] CHECK CONSTRAINT [FK_Link_Bill]
GO

-- %% [markdown]
-- # [FK_Bills_Patient]

-- %%
ALTER TABLE [dbo].[Bills]  WITH CHECK ADD  CONSTRAINT [FK_Bills_Patient] FOREIGN KEY([Assigned_Patient_ID])
REFERENCES [dbo].[Patient] ([Patient_ID])
GO
ALTER TABLE [dbo].[Bills] CHECK CONSTRAINT [FK_Bills_Patient]
GO

-- %% [markdown]
-- # [FK_Doctor_Person]

-- %%
ALTER TABLE [dbo].[Doctor]  WITH CHECK ADD  CONSTRAINT [FK_Doctor_Person] FOREIGN KEY([Person_ID])
REFERENCES [dbo].[Person] ([Person_ID])
GO
ALTER TABLE [dbo].[Doctor] CHECK CONSTRAINT [FK_Doctor_Person]
GO

-- %% [markdown]
-- # [FK_Insurance_Patient]

-- %%
ALTER TABLE [dbo].[Insurance]  WITH CHECK ADD  CONSTRAINT [FK_Insurance_Patient] FOREIGN KEY([Assigned_Patient_ID])
REFERENCES [dbo].[Patient] ([Patient_ID])
GO
ALTER TABLE [dbo].[Insurance] CHECK CONSTRAINT [FK_Insurance_Patient]
GO

-- %% [markdown]
-- # [FK_Medical_Records_Doctor]

-- %%
ALTER TABLE [dbo].[Medical_Records]  WITH CHECK ADD  CONSTRAINT [FK_Medical_Records_Doctor] FOREIGN KEY([Assigned_Doctor_ID])
REFERENCES [dbo].[Doctor] ([Doctor_ID])
GO
ALTER TABLE [dbo].[Medical_Records] CHECK CONSTRAINT [FK_Medical_Records_Doctor]
GO

-- %% [markdown]
-- # [FK_Medical_Records_Patient]

-- %%
ALTER TABLE [dbo].[Medical_Records]  WITH CHECK ADD  CONSTRAINT [FK_Medical_Records_Patient] FOREIGN KEY([Assigned_Patient_ID])
REFERENCES [dbo].[Patient] ([Patient_ID])
GO
ALTER TABLE [dbo].[Medical_Records] CHECK CONSTRAINT [FK_Medical_Records_Patient]
GO

-- %% [markdown]
-- # [FK_Nurse_Person]

-- %%
ALTER TABLE [dbo].[Nurse]  WITH CHECK ADD  CONSTRAINT [FK_Nurse_Person] FOREIGN KEY([Person_ID])
REFERENCES [dbo].[Person] ([Person_ID])
GO
ALTER TABLE [dbo].[Nurse] CHECK CONSTRAINT [FK_Nurse_Person]
GO

-- %% [markdown]
-- # [FK_Patient_Doctor]

-- %%
ALTER TABLE [dbo].[Patient]  WITH CHECK ADD  CONSTRAINT [FK_Patient_Doctor] FOREIGN KEY([Assigned_Doctor_ID])
REFERENCES [dbo].[Doctor] ([Doctor_ID])
GO
ALTER TABLE [dbo].[Patient] CHECK CONSTRAINT [FK_Patient_Doctor]
GO

-- %% [markdown]
-- # [FK_Patient_Nurse]

-- %%
ALTER TABLE [dbo].[Patient]  WITH CHECK ADD  CONSTRAINT [FK_Patient_Nurse] FOREIGN KEY([Assigned_Nurse_ID])
REFERENCES [dbo].[Nurse] ([Nurse_ID])
GO
ALTER TABLE [dbo].[Patient] CHECK CONSTRAINT [FK_Patient_Nurse]
GO

-- %% [markdown]
-- # [FK_Patient_Person]

-- %%
ALTER TABLE [dbo].[Patient]  WITH CHECK ADD  CONSTRAINT [FK_Patient_Person] FOREIGN KEY([Person_ID])
REFERENCES [dbo].[Person] ([Person_ID])
GO
ALTER TABLE [dbo].[Patient] CHECK CONSTRAINT [FK_Patient_Person]
GO

-- %% [markdown]
-- # [FK_Patient_Room]

-- %%
ALTER TABLE [dbo].[Patient]  WITH CHECK ADD  CONSTRAINT [FK_Patient_Room] FOREIGN KEY([Room_ID])
REFERENCES [dbo].[Room] ([Room_ID])
GO
ALTER TABLE [dbo].[Patient] CHECK CONSTRAINT [FK_Patient_Room]
GO

-- %% [markdown]
-- # [FK_Staff_Person]

-- %%
ALTER TABLE [dbo].[Staff]  WITH CHECK ADD  CONSTRAINT [FK_Staff_Person] FOREIGN KEY([Person_ID])
REFERENCES [dbo].[Person] ([Person_ID])
GO
ALTER TABLE [dbo].[Staff] CHECK CONSTRAINT [FK_Staff_Person]
GO

-- %% [markdown]
-- # [FK_User_Person]

-- %%
ALTER TABLE [dbo].[User]  WITH CHECK ADD  CONSTRAINT [FK_User_Person] FOREIGN KEY([Associated_Person_ID])
REFERENCES [dbo].[Person] ([Person_ID])
GO
ALTER TABLE [dbo].[User] CHECK CONSTRAINT [FK_User_Person]
GO

-- %% [markdown]
-- # [Group2-PIS-V2]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [Group2-PIS-V2] SET  READ_WRITE 
GO
